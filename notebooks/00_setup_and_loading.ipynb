# %%
from pathlib import Path
import pandas as pd
import numpy as np

# Confirm it works
print("Notebook environment working")
# Out:
# Notebook environment working

# %%
# Data loading setup
from pathlib import Path
import pandas as pd

# Define the absolute path to your raw data folder
DATA_RAW = Path(r"C:\data-science-project\data\raw")

# Load both CSV datasets
df_food = pd.read_csv(DATA_RAW / "USDA_Food_At_Home.csv")
df_space = pd.read_csv(DATA_RAW / "SAPCE1__ALL_AREAS_1997_2024.csv")

# Display basic info
print("Data loaded successfully")
print("USDA_Food_At_Home shape:", df_food.shape)
print("SAPCE1__ALL_AREAS_1997_2024 shape:", df_space.shape)

# Preview first few rows of USDA dataset
df_food.head()
# Out:
# Data loaded successfully
# USDA_Food_At_Home shape: (48600, 17)
# SAPCE1__ALL_AREAS_1997_2024 shape: (1444, 36)
#    Year  Month           EFPG_name  EFPG_code Metroregion_name  \
# 0  2016      1  Whole-grain breads      10000         National
# 1  2016      2  Whole-grain breads      10000         National
# 2  2016      3  Whole-grain breads      10000         National
# 3  2016      4  Whole-grain breads      10000         National
# 4  2016      5  Whole-grain breads      10000         National
#
#    Metroregion_code Purchase_dollars_wtd Purchase_grams_wtd  \
# 0                 0          195,551,783     37,266,654,290
# 1                 0          188,317,804     35,610,152,589
# 2                 0          193,266,292     36,229,217,927
# 3                 0          186,238,151     35,154,611,318
# 4                 0          188,303,083     35,596,133,635
#
#   Purchase_dollars_unwtd Purchase_grams_unwtd  Number_stores  \
# ...
